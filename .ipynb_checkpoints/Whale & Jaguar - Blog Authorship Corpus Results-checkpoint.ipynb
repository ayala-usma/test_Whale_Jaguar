# %% [markdown]
# # Análisis del Blog Authorship Corpus

# %% [markdown]
# <div style="text-align: right"> <b><i>Por: David Andrés Ayala Usma</i></b> </div>

# %% [markdown]
# ## _Descripción del conjunto de datos_

# %% [markdown]
# El conjunto de datos Blog Authorship Corpus es una colección de entradas de blogs de 19.320 bloggers del portal **blogger.com**. Estas entradas de blog están fechadas hasta agosto de 2004.
#
# Cada fila del conjunto de datos representa una entrada de blog y contiene siete campos: el ID del blogger, género, edad, signo astrológico, tema de discusión de la entrada, la fecha de publicación de la entrada y el texto de la entrada.
#
# Existen tres grupos etarios grandes en el conjunto de datos: los bloggers de 13 a 17 años (8240), los de 23 a 27 años (8086) y los de 33 a 47 años (2994). Todos estos tres grupos están balanceados por género.
#
# Los análisis realizados en este cuaderno se realizaron con una muestra aleatoria del 20% del conjunto de datos original, utilizando el siguiente código:

# %%
###No ejecutar
import pandas as pd
import random

#Muestreo del 20% de las líneas
original_file = 'Dataset/blogtext.csv.tar.gz' #Archivo no disponible por tamaño
p = 0.2
df = pd.read_csv(original_file, header=0, skiprows=lambda i: i>0 and random.random() > p)

#Escribir el conjunto de datos de trabajo
df.to_csv('Dataset/blogtext_sample_0.2.csv.gz', compression='gzip',encoding='utf-8')

# %% [markdown]
# ## _Conjunto de datos y segmentación de los temas de blogging_

# %% [markdown]
# ### Carga de datos

# %%
#Importar los módulos requeridos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Carga del conjunto de datos
data_file = 'Dataset/blogtext_sample_0.2.csv.gz'
dataset = pd.read_csv(data_file, compression='gzip', header = 0)
dataset.head(5)
# Out:
#    Unnamed: 0  blogtext.csv gender  age              topic      sign  \
# 0           0       3581210   male   33  InvestmentBanking  Aquarius
# 1           1       3581210   male   33  InvestmentBanking  Aquarius
# 2           2       3581210   male   33  InvestmentBanking  Aquarius
# 3           3       3581210   male   33  InvestmentBanking  Aquarius
# 4           4       3581210   male   33  InvestmentBanking  Aquarius
#
#            date                                               text
# 0  11,June,2004               Thanks to Yahoo!'s Toolbar I can ...
# 1  29,June,2004                urlLink    The business class ta...
# 2  29,June,2004               I often wondered where the restau...
# 3  07,July,2004               A readers will know, shopping in ...
# 4  14,July,2004               In any developing country (and I ...

# %% [markdown]
# ### Segmentación de temas según la de edad

# %% [markdown]
# Un aspecto interesante del conjunto de datos es saber si existen temas que sean preferentemente discutidos en ciertas edades y no en otros, o si todos los grupos etarios tratan de manera relativamente equitativa estos temas.

# %%
#Gráfica de la distribución de edades por cada tema en el conjunto de datos.
import seaborn as sns

decreasing_order = dataset.groupby(by=["topic"]).median()['age'].sort_values().index

# %%
#Primer panel de distribución de edad por temas
sns.set(rc={'figure.figsize':(20,5)})
sns.boxplot(x='topic', y='age', data=dataset, order=decreasing_order[0:14])

# %%
#Segundo panel de distribución de edad por temas
sns.set(rc={'figure.figsize':(20,5)})
sns.boxplot(x='topic', y='age', data=dataset, order=decreasing_order[14:27])

# %%
#Tercer panel de distribución de edad por temas
sns.set(rc={'figure.figsize':(20,5)})
sns.boxplot(x='topic', y='age', data=dataset, order=decreasing_order[27:41])

# %% [markdown]
# Con el fin de verificar si hay soporte estadístico de los resultados observados, podemos hacer un análisis de varianza (ANOVA) para constatar los hallazgos.

# %%
#Importar módulos
import statsmodels.api as sm
from statsmodels.formula.api import ols

#Ajuste del modelo de ANOVA
aov_model = ols('age ~ C(topic)', data=dataset).fit()
aov_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    age   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     922.2
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               0.00
# Time:                        07:30:21   Log-Likelihood:            -4.5651e+05
# No. Observations:              136105   AIC:                         9.131e+05
# Df Residuals:                  136065   BIC:                         9.135e+05
# Df Model:                          39
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              30.9613      0.249    124.443      0.000      30.474      31.449
# C(topic)[T.Advertising]                -2.4815      0.336     -7.388      0.000      -3.140      -1.823
# C(topic)[T.Agriculture]                -8.0998      0.519    -15.600      0.000      -9.117      -7.082
# C(topic)[T.Architecture]               -4.7543      0.463    -10.261      0.000      -5.662      -3.846
# C(topic)[T.Arts]                       -5.8589      0.263    -22.242      0.000      -6.375      -5.343
# C(topic)[T.Automotive]                 -3.0243      0.513     -5.892      0.000      -4.030      -2.018
# C(topic)[T.Banking]                    -4.7808      0.352    -13.565      0.000      -5.472      -4.090
# C(topic)[T.Biotech]                    -8.2151      0.409    -20.110      0.000      -9.016      -7.414
# C(topic)[T.BusinessServices]           -3.3792      0.335    -10.079      0.000      -4.036      -2.722
# C(topic)[T.Chemicals]                  -8.5995      0.345    -24.949      0.000      -9.275      -7.924
# C(topic)[T.Communications-Media]       -4.6084      0.272    -16.943      0.000      -5.142      -4.075
# C(topic)[T.Construction]               -1.2946      0.533     -2.429      0.015      -2.339      -0.250
# C(topic)[T.Consulting]                 -2.7517      0.318     -8.664      0.000      -3.374      -2.129
# C(topic)[T.Education]                  -4.6655      0.265    -17.632      0.000      -5.184      -4.147
# C(topic)[T.Engineering]                -5.9738      0.289    -20.692      0.000      -6.540      -5.408
# C(topic)[T.Environment]                -7.5227      0.695    -10.827      0.000      -8.884      -6.161
# C(topic)[T.Fashion]                    -0.6519      0.331     -1.968      0.049      -1.301      -0.003
# C(topic)[T.Government]                 -3.7340      0.311    -12.005      0.000      -4.344      -3.124
# C(topic)[T.HumanResources]             -4.7995      0.375    -12.814      0.000      -5.534      -4.065
# C(topic)[T.Internet]                   -1.8757      0.277     -6.769      0.000      -2.419      -1.333
# C(topic)[T.InvestmentBanking]          -2.8024      0.535     -5.240      0.000      -3.851      -1.754
# C(topic)[T.Law]                        -4.3938      0.298    -14.764      0.000      -4.977      -3.810
# C(topic)[T.LawEnforcement-Security]    -4.1220      0.429     -9.602      0.000      -4.963      -3.281
# C(topic)[T.Manufacturing]              -2.2835      0.403     -5.669      0.000      -3.073      -1.494
# C(topic)[T.Maritime]                   -7.5051      0.951     -7.896      0.000      -9.368      -5.642
# C(topic)[T.Marketing]                  -3.5829      0.337    -10.644      0.000      -4.243      -2.923
# C(topic)[T.Military]                   -5.1102      0.375    -13.637      0.000      -5.845      -4.376
# C(topic)[T.Museums-Libraries]          -1.6398      0.378     -4.335      0.000      -2.381      -0.898
# C(topic)[T.Non-Profit]                 -8.0962      0.280    -28.867      0.000      -8.646      -7.546
# C(topic)[T.Publishing]                 -1.5026      0.304     -4.943      0.000      -2.098      -0.907
# C(topic)[T.RealEstate]                 -4.5416      0.377    -12.047      0.000      -5.280      -3.803
# C(topic)[T.Religion]                   -3.1214      0.328     -9.514      0.000      -3.764      -2.478
# C(topic)[T.Science]                    -6.1385      0.308    -19.905      0.000      -6.743      -5.534
# C(topic)[T.Sports-Recreation]          -8.3093      0.379    -21.947      0.000      -9.051      -7.567
# C(topic)[T.Student]                   -13.0571      0.252    -51.831      0.000     -13.551     -12.563
# C(topic)[T.Technology]                 -4.0231      0.260    -15.477      0.000      -4.533      -3.514
# C(topic)[T.Telecommunications]         -2.9242      0.351     -8.330      0.000      -3.612      -2.236
# C(topic)[T.Tourism]                    -5.6818      0.421    -13.486      0.000      -6.508      -4.856
# C(topic)[T.Transportation]              0.1500      0.401      0.374      0.708      -0.636       0.936
# C(topic)[T.indUnk]                     -6.1915      0.251    -24.696      0.000      -6.683      -5.700
# ==============================================================================
# Omnibus:                    11128.799   Durbin-Watson:                   0.234
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14317.535
# Skew:                           0.733   Prob(JB):                         0.00
# Kurtosis:                       3.612   Cond. No.                         94.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### _Resultados:_

# %% [markdown]
# En este análisis de visualización de los diferentes temas en el conjunto de datos, podemos observar que existen dos grandes tipos de temas: aquellos que tienen un amplio rango de edades y aquellos que están casi que restringidos a un rango particular.

# %% [markdown]
# Los temas de "Medio ambiente", "Artes", "Químicos", "Ingeniería", "Turismo", "Ciencia", "Arquitectura", "Banca", "Servicios para negocios", "Leyes", "Gobierno", "Mercadeo" son abordados en su gran mayoría por bloggers con una edad de **25 años y baja participación de otros grupos etarios.**

# %% [markdown]
# Los temas de "Deporte y recreación", "Marítimo", "Biotecnología" y "Sin ánimo de lucro" se encuentran concentrados, particularmente, en usuarios alrededor de los **20 a 25 años**, pero con mayor participación de bloggers de menor edad.

# %% [markdown]
# Las entradas sobre "Estudiantes" se concentran en el rango más bajo de edades, hacia los **15 años**.

# %% [markdown]
# Por otro lado, los temas relativos a "Contabilidad", "Publicidad", "Automotores", "Construcción", "Consultoría", "Educación", "Moda", "Inversión bancaria", "Internet", "Seguridad", "Militar", "Religión", "Finca Raíz", "Publicaciones", "Transporte" y "Telecomunicaciones" se pueden encontrarse de manera relativamente más uniforme en los **diferentes rangos de edad**.
#
# No se observó alguna tendencia especial entre el grupo etario de mayor edad, excepto en temas de contabilidad, donde tienen mayor cantidad de entradas.

# %% [markdown]
# También se observó que las diferencias observadas son estadísticamente significativas, por lo que es posible utilizar estas clasificaciones con cierta confiabilidad para segmentar la población.

# %% [markdown]
# ### Segmentación de temas por género

# %% [markdown]
# Una pregunta interesante que se puede realizar en el conjunto de datos es si existen temas que preferentemente estén siendo abordados por género. Para ello, se puede realizar un análisis de una tabla de contingencia para estas dos variables y realizar una validación estadística de independencia de las variables mediante una prueba de Chi-cuadrado.

# %%
#Importar el módulo requerido para el análisis
from scipy import stats

contingency_table_gender = pd.crosstab(dataset.topic, dataset.gender)

# %%
#Visualización de la tabla de contingencia por género
import seaborn as sns

sns.set(rc={'figure.figsize':(6,10)})
sns.heatmap(contingency_table_gender.drop(index=['Student', 'indUnk']), cmap='Blues')

# %%
#Realizar la prueba estadística y obtención de los resultados
chi2_stat, p_val, dof, ex = stats.chi2_contingency(contingency_table_gender)

print("===Chi2 Stat===")
print(chi2_stat)
print("\n")
print("===Degrees of Freedom===")
print(dof)
print("\n")
print("===P-Value===")
print(p_val)
# Out:
# ===Chi2 Stat===
# 9110.451601222041
#
#
# ===Degrees of Freedom===
# 39
#
#
# ===P-Value===
# 0.0

# %% [markdown]
# #### _Resultados:_

# %% [markdown]
# En este análisis se excluyeron las categorías de "Estudiante" y "indUnk" (categoría desconocida) debido a que distorsionan fuertemente la escala, pero de la tabla de contingencia es posible notar que **no hay diferencias por género en la categoría de "Estudiante"**, pero **más mujeres que hombres tienen entradas de blog con categorías desconocidas.**

# %% [markdown]
# Se observa que los **hombres** suelen abordar **más temas de Tecnología, Internet, Ingeniería, Leyes y Comunicaciones y medios** en sus entradas de blogs con respecto a las mujeres, mientras que las ellas suelen tener mayor contenido de **Artes, Educación, Contaduría y Mercadeo** con respecto a los hombres.

# %% [markdown]
# ### Segmentación de temas por signo zodiacal

# %% [markdown]
# Con el mismo método de análisis también se puede interrogar el conjunto de datos por si existe alguna asociación estadística entre el signo zodiacal y el tema tratado en la entrada de blog.

# %%
#Importar el módulo requerido para el análisis
from scipy import stats

contingency_table_sign = pd.crosstab(dataset.topic, dataset.sign)

# %%
#Visualización de la tabla de contingencia por signo
import seaborn as sns

sns.set(rc={'figure.figsize':(6,9)})
sns.heatmap(contingency_table_sign.drop(index=['Student', 'indUnk']), cmap='Blues')

# %%
#Realizar la prueba estadística y obtención de los resultados
chi2_stat, p_val, dof, ex = stats.chi2_contingency(contingency_table_sign)

print("===Chi2 Stat===")
print(chi2_stat)
print("\n")
print("===Degrees of Freedom===")
print(dof)
print("\n")
print("===P-Value===")
print(p_val)
# Out:
# ===Chi2 Stat===
# 19052.91833336318
#
#
# ===Degrees of Freedom===
# 429
#
#
# ===P-Value===
# 0.0

# %% [markdown]
# #### _Resultados:_

# %% [markdown]
# Para la visualización de este análisis se realizaron las mismas exclusiones del anterior, pero esta vez se observó que no existen diferencias de temas entre los diferentes signos zodiacales.

# %% [markdown]
# Se encontraron diferentes temas para los cuales existe preferencia por el signo zodiacal:

# %% [markdown]
# Se observó que Aries, Tauro, Virgo y Libra son los que más escriben sobre tecnología.

# %% [markdown]
# Los bloggers de signo Géminis son los que más escriben sobre temas "Sin ánimo de lucro".

# %% [markdown]
# Las personas de signo Piscis son las que más escriben sobre temas de internet.

# %% [markdown]
# Las entradas sobre moda las escriben en mayor proporción bloggers de signo Aries.

# %% [markdown]
# Los Libra son los que más escriben sobre ingeniería y artes.

# %% [markdown]
# Géminis, Leo, Acuario y Virgo son los que más escriben sobre educación.

# %% [markdown]
# ## _Entidades más nombradas en el corpus de datos de blogs_

# %% [markdown]
# Con el objetivo de conocer qué entidades y de qué tipo, tales como personas, organizaciones, sitios u otros, se mencionan frecuentemente en el conjunto de datos, podemos utilizar un análisis de _**Name Entity Recognition**_ para extraer esta información a partir del texto de los blogs.

# %% [markdown]
# Para este análisis utilizaremos el paquete SpaCy de Python para procesamiento de texto natural:

# %%
#Importar módulos
import spacy
from spacy import displacy
from collections import Counter


#Importar y aplicar modelos de procesamiento de texto natural en idioma inglés de SpaCy
import en_core_web_sm
nlp = en_core_web_sm.load()

#Añadir algunas "stopwords" para evitar que NLP los reconozca como términos
customize_stop_words = ['Here','Ah', 'Well', 'Yeah', 'Anyways', 'urlLink', 'Ok']
for w in customize_stop_words:
    nlp.vocab[w].is_stop = True

# %% [markdown]
# Para recuperar las entidades reconocidas por el modelo de lenguaje y calcular las frecuencias de cada una, creamos un arreglo que contendrá las entidades identificadas en todo el conjunto de datos y realizamos un reconocimiento de entidades por cada entrada:

# %%
#Arreglo de entidades
entities = []

#Reconocimiento de entidades por cada entrada y almacenar únicamente aquellas referentes a personas (PERSON),
#lugares (LOC o GPE) o productos (PRODUCT).
for index, row in dataset.iterrows():
    row_processing = nlp(str(row["text"]))
    entities += [(entity.text, entity.label_) for entity in row_processing.ents if entity.label_ == "PERSON" or entity.label_ == "LOC" or entity.label_ == "GPE" or entity.label_ == "PRODUCT" ]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-d384b14d23e5> in <module>
#       5 #lugares (LOC o GPE) o productos (PRODUCT).
#       6 for index, row in dataset.iterrows():
# ----> 7     row_processing = nlp(str(row["text"]))
#       8     entities += [(entity.text, entity.label_) for entity in row_processing.ents if entity.label_ == "PERSON" or entity.label_ == "LOC" or entity.label_ == "GPE" or entity.label_ == "PRODUCT" ]
#
# ~/miniconda3/lib/python3.5/site-packages/spacy/language.py in __call__(self, text, disable)
#     350             if not hasattr(proc, '__call__'):
#     351                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 352             doc = proc(doc)
#     353             if doc is None:
#     354                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# nn_parser.pyx in spacy.syntax.nn_parser.precompute_hiddens.__init__()
#
# ~/miniconda3/lib/python3.5/site-packages/spacy/_ml.py in begin_update(self, X, drop)
#     147     def begin_update(self, X, drop=0.):
#     148         Yf = self.ops.xp.dot(X,
# --> 149             self.W.reshape((self.nF*self.nO*self.nP, self.nI)).T)
#     150         Yf = Yf.reshape((Yf.shape[0], self.nF, self.nO, self.nP))
#     151         Yf = self._add_padding(Yf)
#
# MemoryError:

# %% [markdown]
# Retiramos los espacios, caracteres vacíos y demás elementos no informativos del arreglo de entidades, almacenamos en arreglos nuevos que nos permitan discriminar por las diferentes categorías buscadas y realizamos los recuentos de entidades sobrerrepresentadas en los blogs.

# %%
#Creación del nuevo arreglo de entidades
curated_people = []
curated_places = []
curated_products = []

#Retirar resultados no informativos y generar los arreglos con los elementos por tipo
for element in entities:
    name_entity = element[0].strip()
    type_entity = element[1].strip()
    if (name_entity != ''):
        if (type_entity == 'PERSON'):
            curated_people += [element]
        elif (type_entity == 'GPE' or type_entity == 'LOC'):
            curated_places += [element]
        else:
            curated_products += [element]

# %% [markdown]
# Generación de la tabla de conteos con los 20 términos más frecuentes por cada categoría

# %%
#Las 20 personas más frecuentes
Counter(curated_people).most_common()[1:20]
# Out:
# [(('Jesus', 'PERSON'), 1758),
#  (('Chris', 'PERSON'), 1321),
#  (('John', 'PERSON'), 1113),
#  (('Matt', 'PERSON'), 1070),
#  (('Mike', 'PERSON'), 1038),
#  (('Paul', 'PERSON'), 1033),
#  (('Haha', 'PERSON'), 963),
#  (('God', 'PERSON'), 902),
#  (('Sarah', 'PERSON'), 824),
#  (('Kerry', 'PERSON'), 821),
#  (('SBristowSD6', 'PERSON'), 772),
#  (('David', 'PERSON'), 723),
#  (('Dave', 'PERSON'), 711),
#  (('Michael', 'PERSON'), 684),
#  (('Josh', 'PERSON'), 679),
#  (('Brian', 'PERSON'), 659),
#  (('Joe', 'PERSON'), 657),
#  (('Dan', 'PERSON'), 655),
#  (('Ryan', 'PERSON'), 645)]

# %%
#Los 20 lugares más frecuentes
Counter(curated_places).most_common()[1:20]
# Out:
# [(('America', 'GPE'), 1978),
#  (('US', 'GPE'), 1686),
#  (('U  ', 'LOC'), 1315),
#  (('U.S.', 'GPE'), 1280),
#  (('New York', 'GPE'), 899),
#  (('China', 'GPE'), 878),
#  (('California', 'GPE'), 864),
#  (('Texas', 'GPE'), 825),
#  (('Chicago', 'GPE'), 773),
#  (('the United States', 'GPE'), 727),
#  (('Canada', 'GPE'), 704),
#  (('India', 'GPE'), 642),
#  (('London', 'GPE'), 624),
#  (('Kerry', 'GPE'), 612),
#  (('Florida', 'GPE'), 603),
#  (('Japan', 'GPE'), 601),
#  (('England', 'GPE'), 569),
#  (('Israel', 'GPE'), 541),
#  (('France', 'GPE'), 537)]

# %%
#Los 20 productos más frecuentes
Counter(curated_products).most_common()[1:20]
# Out:
# [(('Jessica', 'PRODUCT'), 207),
#  (('Baby', 'PRODUCT'), 136),
#  (('Jimmy', 'PRODUCT'), 136),
#  (('Green Knight', 'PRODUCT'), 110),
#  (('Google', 'PRODUCT'), 71),
#  (('Geo', 'PRODUCT'), 66),
#  (('Click', 'PRODUCT'), 65),
#  (('Netscape', 'PRODUCT'), 62),
#  (('Notes', 'PRODUCT'), 49),
#  (('Excel', 'PRODUCT'), 46),
#  (('Blogger', 'PRODUCT'), 43),
#  (('Surprisingly', 'PRODUCT'), 43),
#  (('Saturn', 'PRODUCT'), 42),
#  (('Captain', 'PRODUCT'), 41),
#  (('Apache', 'PRODUCT'), 41),
#  (('Ya', 'PRODUCT'), 41),
#  (('Sky', 'PRODUCT'), 40),
#  (('Diet Coke', 'PRODUCT'), 38),
#  (('Superman', 'PRODUCT'), 38)]

# %% [markdown]
# #### _Resultados_

# %% [markdown]
# La persona mencionada más frecuentemente por los bloggers es "Jesus", seguido por una gran cantidad de nombres de hombre en inglés, un nombre de mujer "Sarah", el término "Haha" por determinar y "God". Esto revela un sesgo del uso de blogs por parte de angloparlantes y una gran cantidad de referencias religiosas en los textos.

# %% [markdown]
# Es notable que el lugar más frecuentemente mencionado es los Estados Unidos referenciado tanto como país como en varios lugares dentro del él, lo cual evidencia un sesgo hacia los habitantes de este país. También están dos de los países más populosos del mundo, China e India y naciones occidentales como Francia, Inglaterra, Canadá e Israel.

# %% [markdown]
# Dentro de los productos más frecuentemente mencionados destacan productos informáticos como Google, Excel, Netscape, Apache y Blogger, pero también un producto de consumo que es la Diet Coke. Esto puede estar dando cuenta de las tendencias de uso de software de los bloggers.
#
# La clasificación de productos muestra una gran cantidad de ruido, ya que se encuentran nombres propios como Jessica y Jimmy, sustantivos como Captain, Baby y Saturn y otros términos de clasificación ambigua como Superman, Sky y otros.
